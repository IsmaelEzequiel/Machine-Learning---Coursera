# %% [markdown]
# # Fire up Pandas, Matplotlib and Start Use XD

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('home_data.csv')
sales = pd.DataFrame(data)

# %% [markdown]
# # Exploring the data for house sales

# %%
sales.plot(kind='scatter', x='sqft_living', y='price')

# %% [markdown]
# # Creating simple prediction

# %%
# Using numpy for load my data and getting 80% of the data to use how train
mask = np.random.rand(len(sales)) < 0.8

# %%
train = sales[mask]

# %%
# the ~ is to get the rest of the datas
test = sales[~mask]

# %%
plt.scatter(sales['sqft_living'], sales['price'])
plt.xlabel('Sqft House')
plt.ylabel('Price')
plt.title('House Analysis')
plt.show()

# %%
test.plot(kind='scatter', x='sqft_living', y='price') # Train_Error

# %%
train.plot(kind='scatter', x='sqft_living', y='price') # Train_Data for pradiction

# %%
pd.DataFrame(train).head()
# Out:
#            id             date    price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900         3       1.00         1180
# 2  5631500400  20150225T000000   180000         2       1.00          770
# 3  2487200875  20141209T000000   604000         4       3.00         1960
# 5  7237550310  20140512T000000  1225000         4       4.50         5420
# 6  1321400060  20140627T000000   257500         3       2.25         1715
#
#    sqft_lot  floors  waterfront  view  ...   grade  sqft_above  sqft_basement  \
# 0      5650       1           0     0  ...       7        1180              0
# 2     10000       1           0     0  ...       6         770              0
# 3      5000       1           0     0  ...       7        1050            910
# 5    101930       1           0     0  ...      11        3890           1530
# 6      6819       2           0     0  ...       7        1715              0
#
# ...

# %% [markdown]
# # Explore other features in data

# %%
my_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors','zipcode']

# %%
sales[my_features].describe()
# Out:
#            bedrooms     bathrooms   sqft_living        sqft_lot        floors  \
# count  21613.000000  21613.000000  21613.000000    21613.000000  21613.000000
# mean       3.370842      2.114757   2079.899736    15106.967566      1.494309
# std        0.930062      0.770163    918.440897    41420.511515      0.539989
# min        0.000000      0.000000    290.000000      520.000000      1.000000
# 25%        3.000000      1.750000   1427.000000     5040.000000      1.000000
# 50%        3.000000      2.250000   1910.000000     7618.000000      1.500000
# 75%        4.000000      2.500000   2550.000000    10688.000000      2.000000
# max       33.000000      8.000000  13540.000000  1651359.000000      3.500000
#
#             zipcode
# count  21613.000000
# mean   98077.939805
# std       53.505026
# min    98001.000000
# 25%    98033.000000
# 50%    98065.000000
# 75%    98118.000000
# max    98199.000000

# %%
plt.boxplot(sales['zipcode'], sales['price'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-92366ef4010d> in <module>()
# ----> 1 plt.boxplot(sales['zipcode'], sales['price'])
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_xticks, hold)
#    2640                          flierprops=flierprops, medianprops=medianprops,
#    2641                          meanprops=meanprops, capprops=capprops,
# -> 2642                          whiskerprops=whiskerprops, manage_xticks=manage_xticks)
#    2643         draw_if_interactive()
#    2644     finally:
#
# ...
